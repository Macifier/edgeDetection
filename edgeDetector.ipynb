# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from skimage import feature , io
img = io.imread("/content/drive/My Drive/edgeDetector/canny_edge_detector/faces_imgs/4.jpg",as_gray=True)
modified_img = feature.canny(img, sigma=2)
plt.subplots(nrows=1, ncols=1, figsize=(10, 6) , sharex=True, sharey=True)
plt.imshow(modified_img, cmap=plt.cm.gray)
plt.show()
img2 = io.imread("/content/drive/My Drive/edgeDetector/canny_edge_detector/faces_imgs/clock.jpg",as_gray=True)
modified_img2 = feature.canny(img2, sigma=3)
plt.subplots(nrows=1, ncols=1, figsize=(10, 6) , sharex=True, sharey=True)
plt.imshow(modified_img2, cmap=plt.cm.gray)
